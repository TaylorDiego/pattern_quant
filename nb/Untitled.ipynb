# %%
from collections import Counter
import numpy as np
import skfuzzy as fuzz
from skimage import data

# %%
import PIL
import PIL.Image as Image
from io import BytesIO

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = Image.open("../data/hong_kong_boat.png")
pic = np.asarray(img) #as rgba array
# img = Image.open(BytesIO(pic)).convert('RGBA')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1704x954 at 0x109735080>

# %%
pic.shape
# Out:
# (954, 1704, 3)

# %%
pic.size
# Out:
# 4876848

# %%
pic = pic[:,:,0:3] #remove alpha layer; no transparency

# %%
pic[2,2,:]
# Out:
# array([209, 168, 149], dtype=uint8)

# %%
def raw_pixel_color(pic):
    dict_raw_pixel_color = {}
# Out:
# array([[[209, 168, 149],
#         [209, 168, 149],
#         [209, 168, 149],
#         ...,
#         [232, 195, 168],
#         [232, 195, 168],
#         [233, 196, 169]],
#
#        [[209, 168, 149],
#         [209, 168, 149],
#         [209, 168, 149],
#         ...,
#         [232, 195, 168],
#         [232, 195, 168],
#         [233, 196, 169]],
#
#        [[209, 168, 149],
#         [209, 168, 149],
#         [209, 168, 149],
#         ...,
#         [232, 195, 168],
#         [232, 195, 168],
#         [233, 196, 169]],
#
#        ...,
#        [[ 44,  59,  28],
#         [ 41,  56,  25],
#         [ 36,  51,  20],
#         ...,
#         [104, 115,  83],
#         [106, 117,  85],
#         [109, 120,  88]],
#
#        [[ 44,  59,  28],
#         [ 42,  56,  25],
#         [ 37,  52,  21],
#         ...,
#         [ 81,  93,  61],
#         [ 83,  94,  63],
#         [ 85,  96,  65]],
#
#        [[ 45,  59,  28],
#         [ 44,  57,  27],
#         [ 40,  54,  24],
#         ...,
#         [ 48,  61,  31],
#         [ 48,  61,  31],
#         [ 49,  62,  31]]], dtype=uint8)
